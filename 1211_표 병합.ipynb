# %%
import pandas as pd

# %%
#issue
#- 행 (서울시 = 합계 : 데이터 13)

# %%
#데이터 1 
df01 = pd.read_excel('데이터/01_서울시 주민등록인구 (구별)통계_05-18.xls', header=2)
df01_ft=df01[['기간', '자치구','계.1','남자.1','여자.1']]
df01_ft.rename(columns={'기간':'년도','계.1':'사람 수','남자.1':'남자수', '여자.1':'여자수'}, inplace = True)
df01_ft
# Out:
#        년도  자치구      사람 수      남자수      여자수
# 0    2005   합계  10167344  5062492  5104852
# 1    2005  종로구    169315    84981    84334
# 2    2005   중구    130027    64995    65032
# 3    2005  용산구    230260   113158   117102
# 4    2005  성동구    337744   169346   168398
# ..    ...  ...       ...      ...      ...
# 359  2018  관악구    501957   252160   249797
# 360  2018  서초구    433951   207868   226083
# 361  2018  강남구    542364   259611   282753
# 362  2018  송파구    666635   323526   343109
# 363  2018  강동구    427573   211816   215757
#
# [364 rows x 5 columns]

# %%
#데이터 2
df02= pd.read_excel('데이터/02_서울시 유기동물보호 현황 통계(05~18).xls', header=2)
df02_ft=df02[['기간','자치구','계','인도(주인)','입양분양','폐사안락사','계류기증']]
df02_ft.rename(columns={'기간':'년도',"계":"유기견수","인도(주인)":"복귀"}, inplace = True)
df02_ft
# Out:
#        년도  자치구   유기견수   복귀  입양분양  폐사안락사  계류기증
# 0    2005   합계  14679  601   525   7736  5817
# 1    2005  종로구    258   12     3     89   154
# 2    2005   중구    264    0     9    102   153
# 3    2005  용산구    383   12    12    170   189
# 4    2005  성동구    431   19     7     96   309
# ..    ...  ...    ...  ...   ...    ...   ...
# 359  2018  관악구    493  207   275     11     -
# 360  2018  서초구    124   42    15     64     3
# 361  2018  강남구    158   58    41     57     2
# 362  2018  송파구    211   57    62     90     2
# 363  2018  강동구    291  130   107     52     2
#
# [364 rows x 7 columns]

# %%
#데이터 결과 = 데이터 1 + 데이터 2
df_result=pd.merge(df01_ft,df02_ft)
df_result
# Out:
#        년도  자치구      사람 수      남자수      여자수   유기견수   복귀  입양분양  폐사안락사  계류기증
# 0    2005   합계  10167344  5062492  5104852  14679  601   525   7736  5817
# 1    2005  종로구    169315    84981    84334    258   12     3     89   154
# 2    2005   중구    130027    64995    65032    264    0     9    102   153
# 3    2005  용산구    230260   113158   117102    383   12    12    170   189
# 4    2005  성동구    337744   169346   168398    431   19     7     96   309
# ..    ...  ...       ...      ...      ...    ...  ...   ...    ...   ...
# 359  2018  관악구    501957   252160   249797    493  207   275     11     -
# 360  2018  서초구    433951   207868   226083    124   42    15     64     3
# 361  2018  강남구    542364   259611   282753    158   58    41     57     2
# 362  2018  송파구    666635   323526   343109    211   57    62     90     2
# 363  2018  강동구    427573   211816   215757    291  130   107     52     2
#
# [364 rows x 10 columns]

# %%
#데이터 3 (서울시 / 합계 이슈)
df03 = pd.read_excel('데이터/03_서울시 반려동물 유무 및 취득 경로 통계(14~18).xls', header=1)
df03.rename(columns={"대분류":"자치구", "기간":"년도"}, inplace = True)
a = df03.loc[0,'자치구']
df03 = df03.replace(a,'합계')
df03
# Out:
#        년도  자치구      분류    있다    없다 동물판매업소  유상입양  무상입양 인터넷을 통해 구입 유기동물 입양  \
# 0    2014   합계      합계  19.4  80.6   34.6  18.9  39.4        1.8     3.5
# 1    2014   성별      남자  18.8  81.2     35    18  39.9        1.9     3.3
# 2    2014   성별      여자  22.5  77.5   32.9  23.1  37.2        1.2     4.4
# 3    2014  연령별  20대 이하  21.5  78.5     42  20.4  33.1        1.7     2.2
# 4    2014  연령별     30대  15.5  84.5   36.4  18.6  39.5        2.7     3.1
# ..    ...  ...     ...   ...   ...    ...   ...   ...        ...     ...
# 295  2018  관악구     관악구     …     …      -     -     -          -       -
# 296  2018  서초구     서초구     …     …      -     -     -          -       -
# 297  2018  강남구     강남구     …     …      -     -     -          -       -
# 298  2018  송파구     송파구     …     …      -     -     -          -       -
# 299  2018  강동구     강동구     …     …      -     -     -          -       -
#
#     원래 기르던 동물이 낳은 새끼   기타
# 0                7.2  0.1
# 1                7.1  0.1
# ...

# %%
#데이터 결과 = 데이터 결과 +데이터 3
df_result = pd.merge(df_result, df03, how='outer')
df_result
# Out:
#        년도    자치구        사람 수        남자수        여자수     유기견수     복귀   입양분양  \
# 0    2005     합계  10167344.0  5062492.0  5104852.0  14679.0  601.0  525.0
# 1    2005    종로구    169315.0    84981.0    84334.0    258.0   12.0    3.0
# 2    2005     중구    130027.0    64995.0    65032.0    264.0    0.0    9.0
# 3    2005    용산구    230260.0   113158.0   117102.0    383.0   12.0   12.0
# 4    2005    성동구    337744.0   169346.0   168398.0    431.0   19.0    7.0
# ..    ...    ...         ...        ...        ...      ...    ...    ...
# 529  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 530  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 531  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 532  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 533  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
#
#       폐사안락사  계류기증   분류    있다    없다 동물판매업소 유상입양 무상입양 인터넷을 통해 구입 유기동물 입양  \
# ...

# %%
#데이터 6
df06 = pd.read_excel('데이터/06_서울시 가구원수별 가구수(구별) 통계(05,10,15,16,17,18).xls', header=1)
df06.rename(columns={'구분':'자치구', '기간':'년도'}, inplace = True)
df06
# Out:
#        년도  자치구        계    1인가구    2인가구    3인가구    4인가구   5인 가구   6인가구  \
# 0    2005   합계  3309890  675739  670455  732043  917243  248450  49781
# 1    2005  종로구    54534   14592   11641   10624   12373    4087    905
# 2    2005   중구    46625   13128    9833    9270    9961    3538    627
# 3    2005  용산구    76125   18218   18032   16187   17302    4902   1088
# 4    2005  성동구   111485   23161   24104   24784   28823    8263   1756
# ..    ...  ...      ...     ...     ...     ...     ...     ...    ...
# 151  2018  관악구   236761  112733   54106   35925   25997    6172   1451
# 152  2018  서초구   155418   41137   38475   35620   31029    7112   1598
# 153  2018  강남구   203083   62727   50076   43542   36572    8063   1664
# 154  2018  송파구   243547   63451   61970   56824   48156   10366   2235
# 155  2018  강동구   159233   42126   41450   36503   30197    7084   1468
#
#      7인이상 가구  평균가구원수
# 0      16179     2.9
# 1        312     2.7
# 2        268     2.7
# 3        396     2.7
# ...

# %%
#데이터 결과 = 데이터 결과 + 데이터 6
df_result = pd.merge(df_result, df06, how='outer')
df_result
# Out:
#        년도    자치구        사람 수        남자수        여자수     유기견수     복귀   입양분양  \
# 0    2005     합계  10167344.0  5062492.0  5104852.0  14679.0  601.0  525.0
# 1    2005    종로구    169315.0    84981.0    84334.0    258.0   12.0    3.0
# 2    2005     중구    130027.0    64995.0    65032.0    264.0    0.0    9.0
# 3    2005    용산구    230260.0   113158.0   117102.0    383.0   12.0   12.0
# 4    2005    성동구    337744.0   169346.0   168398.0    431.0   19.0    7.0
# ..    ...    ...         ...        ...        ...      ...    ...    ...
# 529  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 530  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 531  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 532  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 533  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
#
#       폐사안락사  계류기증  ...   기타          계      1인가구      2인가구      3인가구  \
# ...

# %%
#데이터 11
df11 = pd.read_excel('데이터/11_서울시 세대원수별 세대수(구별) 통계(13~18).xls', header=0)
df11.rename(columns={'기간':'년도'}, inplace = True)
df11
# Out:
#        년도  자치구     전체세대     1인세대    2인세대    3인세대    4인세대    5인세대   6인세대  7인세대  \
# 0    2013   합계  4182351  1510202  810516  780698  822832  200130  44057  9977
# 1    2013  종로구    73693    34259   13213   11146   10932    3123    755   197
# 2    2013   중구    60600    27959   11709    9385    8515    2287    548   137
# 3    2013  용산구   109361    48569   21093   17772   16371    4208    984   244
# 4    2013  성동구   126447    47609   25016   23452   22951    5613   1370   316
# ..    ...  ...      ...      ...     ...     ...     ...     ...    ...   ...
# 151  2018  관악구   262222   142742   48591   33787   28087    6823   1576   425
# 152  2018  서초구   172918    57213   34019   34110   35896    8780   2067   552
# 153  2018  강남구   228775    88584   42357   40866   43665   10097   2292   618
# 154  2018  송파구   270866    90734   55726   54172   54371   12242   2704   623
# 155  2018  강동구   177247    61564   37946   34542   32974    7933   1695   429
#
#      8인세대  9인세대  10인세대 이상
# ...

# %%
#데이터 결과 = 데이터 결과 + 데이터 11
df_result = pd.merge(df_result, df11, how='outer')
df_result
# Out:
#        년도    자치구        사람 수        남자수        여자수     유기견수     복귀   입양분양  \
# 0    2005     합계  10167344.0  5062492.0  5104852.0  14679.0  601.0  525.0
# 1    2005    종로구    169315.0    84981.0    84334.0    258.0   12.0    3.0
# 2    2005     중구    130027.0    64995.0    65032.0    264.0    0.0    9.0
# 3    2005    용산구    230260.0   113158.0   117102.0    383.0   12.0   12.0
# 4    2005    성동구    337744.0   169346.0   168398.0    431.0   19.0    7.0
# ..    ...    ...         ...        ...        ...      ...    ...    ...
# 529  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 530  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 531  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 532  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 533  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
#
#       폐사안락사  계류기증  ... 1인세대 2인세대 3인세대 4인세대 5인세대 6인세대 7인세대 8인세대 9인세대 10인세대 이상
# ...

# %%
#데이터 13 (서울시 / 합계 이슈)
df13 = pd.read_excel('데이터/13_서울시 주택종류별 주택(구별) 통계(15~18).xls', header=2)
df13_ft=df13[['기간','자치구','소계','아파트','연립주택','다세대주택','비거주용 건물내 주택']]
df13_ft.rename(columns={'기간':'년도'}, inplace = True)
a = df13_ft.loc[0,'자치구']
df13_ft = df13_ft.replace(a,'합계')
df13_ft
# Out:
#        년도  자치구      소계      아파트    연립주택   다세대주택  비거주용 건물내 주택
# 0    2015   합계  355039  1636896  117235  654372        29702
# 1    2015  종로구   13103    12552    5395   11664          836
# 2    2015   중구    6436    22186    1975    6148          733
# 3    2015  용산구   15503    35343    4029   15206          642
# 4    2015  성동구   11250    59331    2076    8610         1064
# ..    ...  ...     ...      ...     ...     ...          ...
# 99   2018  관악구   21584    53915    6442   41274         1933
# 100  2018  서초구    6395    93299    5592   25426         1328
# 101  2018  강남구    7283   124418    6121   31817         1792
# 102  2018  송파구    8441   119226    4797   65656         1619
# 103  2018  강동구   10467    75473    3512   32149         1117
#
# [104 rows x 7 columns]

# %%
#데이터 결과 = 데이터 결과 + 데이터 13
df_result = pd.merge(df_result, df13_ft, how='outer')
df_result
# Out:
#        년도    자치구        사람 수        남자수        여자수     유기견수     복귀   입양분양  \
# 0    2005     합계  10167344.0  5062492.0  5104852.0  14679.0  601.0  525.0
# 1    2005    종로구    169315.0    84981.0    84334.0    258.0   12.0    3.0
# 2    2005     중구    130027.0    64995.0    65032.0    264.0    0.0    9.0
# 3    2005    용산구    230260.0   113158.0   117102.0    383.0   12.0   12.0
# 4    2005    성동구    337744.0   169346.0   168398.0    431.0   19.0    7.0
# ..    ...    ...         ...        ...        ...      ...    ...    ...
# 529  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 530  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 531  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 532  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
# 533  2018  지역대분류         NaN        NaN        NaN      NaN    NaN    NaN
#
#       폐사안락사  계류기증  ... 6인세대 7인세대 8인세대 9인세대 10인세대 이상  소계 아파트 연립주택 다세대주택  \
# ...

# %%
#데이터 07
df07 = pd.read_excel('데이터/07_서울시 공원 (공원율) 통계 [10-18].xls', header=1)
df07_ft=df07[['기간','구분','행정구역면적(㎡)','합계','공원율(%)']]
df07_ft.rename(columns={'기간':'년도', '구분':'자치구','합계':'공원면적(㎡)'}, inplace = True)
df07_ft
# Out:
#        년도    자치구  행정구역면적(㎡)    공원면적(㎡) 공원율(%)
# 0    2010     합계  605251484  169792302  28.05
# 1    2010    종로구   23907423   10900949   45.6
# 2    2010     중구    9959933    3125323  31.38
# 3    2010    용산구   21867354    1350163   6.17
# 4    2010    성동구   16848684    2869532  17.03
# ..    ...    ...        ...        ...    ...
# 238  2018    서초구   46982024   16036321  34.13
# 239  2018    강남구   39501308    6591655  16.69
# 240  2018    송파구   33876548    4642075   13.7
# 241  2018    강동구   24589280    3369970  13.71
# 242  2018  서울대공원          -    6670000      -
#
# [243 rows x 5 columns]

# %%
#데이터 결과= 데이터 결과 + 데이터 07
df_result = pd.merge(df_result, df07_ft, how='outer')
df_result
# Out:
#        년도    자치구        사람 수        남자수        여자수     유기견수     복귀   입양분양  \
# 0    2005     합계  10167344.0  5062492.0  5104852.0  14679.0  601.0  525.0
# 1    2005    종로구    169315.0    84981.0    84334.0    258.0   12.0    3.0
# 2    2005     중구    130027.0    64995.0    65032.0    264.0    0.0    9.0
# 3    2005    용산구    230260.0   113158.0   117102.0    383.0   12.0   12.0
# 4    2005    성동구    337744.0   169346.0   168398.0    431.0   19.0    7.0
# ..    ...    ...         ...        ...        ...      ...    ...    ...
# 538  2014  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
# 539  2015  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
# 540  2016  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
# 541  2017  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
# 542  2018  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
#
#       폐사안락사  계류기증  ... 9인세대 10인세대 이상  소계 아파트 연립주택 다세대주택 비거주용 건물내 주택 행정구역면적(㎡)  \
# ...

# %%
#데이터 08
df08 = pd.read_excel('데이터/08_서울시 공원 통계 [13-18].xls', header=2)
df08_ft=df08[['기간','자치구','공원수']]
df08_ft.rename(columns={'기간':'년도', '공원수':'공원 계'}, inplace = True)
df08_ft
# Out:
#        년도    자치구  공원 계
# 0    2013     합계  2782
# 1    2013    종로구   114
# 2    2013     중구    68
# 3    2013    용산구   101
# 4    2013    성동구    80
# ..    ...    ...   ...
# 157  2018    서초구   165
# 158  2018    강남구   155
# 159  2018    송파구   168
# 160  2018    강동구   124
# 161  2018  서울대공원     1
#
# [162 rows x 3 columns]

# %%
#데이터 결과= 데이터 결과 + 데이터 08
df_result = pd.merge(df_result, df08_ft, how='outer')
df_result
# Out:
#        년도    자치구        사람 수        남자수        여자수     유기견수     복귀   입양분양  \
# 0    2005     합계  10167344.0  5062492.0  5104852.0  14679.0  601.0  525.0
# 1    2005    종로구    169315.0    84981.0    84334.0    258.0   12.0    3.0
# 2    2005     중구    130027.0    64995.0    65032.0    264.0    0.0    9.0
# 3    2005    용산구    230260.0   113158.0   117102.0    383.0   12.0   12.0
# 4    2005    성동구    337744.0   169346.0   168398.0    431.0   19.0    7.0
# ..    ...    ...         ...        ...        ...      ...    ...    ...
# 538  2014  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
# 539  2015  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
# 540  2016  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
# 541  2017  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
# 542  2018  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
#
#       폐사안락사  계류기증  ... 10인세대 이상  소계 아파트 연립주택 다세대주택 비거주용 건물내 주택 행정구역면적(㎡)  \
# ...

# %%
#데이터 14
# pd.read_excel('엑셀파일명.xlsx', sheet_name = '시트이름')

df14 = pd.read_excel('데이터/14_서울시 직업유형별 취업인구 (구별) 통계(10,15)_set.xls',  header=1)
#df14_ft=df14[['기간','행정구역','직업유형','합계']]
#df14_ft.rename(columns={'기간':'년도','행정구역':'자치구'}, inplace = True)
df14
type(df14)
# Out:
# pandas.core.frame.DataFrame

# %%
#데이터 결과= 데이터 결과 + 데이터14
df_reee= pd.merge(df13333, df14, how='outer').dtypes
df_reee
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-043b61fc8a13> in <module>
#       1 #데이터 결과= 데이터 결과 + 데이터14
# ----> 2 df_reee= pd.merge(df13333, df14, how='outer').dtypes
#       3 df_reee
#       4
#
# C:\ai\python\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# C:\ai\python\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     628         # validate the merge keys dtypes. We may need to coerce
# ...

# %%
df.convert_objects(convert_numeric=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-9da24c072a2b> in <module>
# ----> 1 df.convert_objects(convert_numeric=True)
#
# NameError: name 'df' is not defined

# %%
pd.merge(df13333, df14,how='outer').dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-17719ea30c02> in <module>
# ----> 1 pd.merge(df13333, df14,how='outer').dtypes
#
# C:\ai\python\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# C:\ai\python\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     628         # validate the merge keys dtypes. We may need to coerce
#     629         # to avoid incompat dtypes
# --> 630         self._maybe_coerce_merge_keys()
#     631
# ...

# %%
pd.concat([df13333,df14]).dtypes
# Out:
# C:\ai\python\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# 10인세대 이상            float64
# 1인가구                float64
# 1인세대                float64
# 2인가구                float64
# 2인세대                float64
# 3인가구                float64
# 3인세대                float64
# 4인가구                float64
# 4인세대                float64
# 5인 가구               float64
# 5인세대                float64
# 6인가구                float64
# 6인세대                float64
# 7인세대                float64
# 7인이상 가구             float64
# 8인세대                float64
# 9인세대                float64
# 계                   float64
# 계류기증                 object
# 공원 계                float64
# ...

# %%
data_x.merge(data_y, on='key')

# %%
df_result.astype(int)
df14.astype(int)
df_re2 = df_result.merge(df14)

df_re2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-2659dbf4a336> in <module>
# ----> 1 df_result.astype(int)
#       2 df14.astype(int)
#       3 df_re2 = df_result.merge(df14)
#       4
#       5 df_re2
#
# C:\ai\python\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# C:\ai\python\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
# ...

# %%
df14
# Out:
#       년도   자치구       소계     관리자  전문가 및 관련종사자   사무종사자  서비스종사자   판매종사자  \
# 0   2010    합계  4609336  192621      1166525  929604  480995  658545
# 1   2010   종로구    71986    2717        17824   12858    8468   11519
# 2   2010    중구    59446    1572        11395   10352    6771   11646
# 3   2010   용산구   107961    5008        28177   21806   12051   17264
# 4   2010   성동구   142092    4981        32435   27964   14240   21081
# 5   2010   광진구   180414    6418        44713   34641   20682   26444
# 6   2010  동대문구   159172    4249        32597   29048   16340   29871
# 7   2010   중랑구   195893    3873        34367   31129   22404   32293
# 8   2010   성북구   213319    7275        48901   39957   22449   34455
# 9   2010   강북구   152035    3381        27178   26925   17324   25243
# 10  2010   도봉구   160753    5051        34350   30030   16935   26230
# 11  2010   노원구   253521   10543        65122   52302   25329   35305
# 12  2010   은평구   210227    5985        46648   40347   24099   32108
# ...

# %%
#

# %%
df13333 = pd.read_csv('./result_test.csv',  header=0, encoding='euc-kr' )
df13333
# Out:
#        년도    자치구        사람 수        남자수        여자수     유기견수     복귀   입양분양  \
# 0    2005     합계  10167344.0  5062492.0  5104852.0  14679.0  601.0  525.0
# 1    2005    종로구    169315.0    84981.0    84334.0    258.0   12.0    3.0
# 2    2005     중구    130027.0    64995.0    65032.0    264.0    0.0    9.0
# 3    2005    용산구    230260.0   113158.0   117102.0    383.0   12.0   12.0
# 4    2005    성동구    337744.0   169346.0   168398.0    431.0   19.0    7.0
# ..    ...    ...         ...        ...        ...      ...    ...    ...
# 538  2014  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
# 539  2015  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
# 540  2016  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
# 541  2017  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
# 542  2018  서울대공원         NaN        NaN        NaN      NaN    NaN    NaN
#
#       폐사안락사  계류기증  ... 10인세대 이상  소계 아파트 연립주택 다세대주택 비거주용 건물내 주택 행정구역면적(㎡)  \
# ...

# %%
df_re[df_re['년도']>=2014]

# %%
df_result.to_csv("./result_test.csv", encoding='euc-kr')

# %%
#데이터 14

#컬럼의 이름으로 변경할 데이터 값 추출
col_name = list(df14_ft.iloc[1:12,2])
col_name

# '직업유형' 행에서 열로 이동
for i in range(len(col_name)):
    df14_ft[f'{col_name[i]}'] = 0

df14_ft

#데이터 값 추출
col_total2 =  list(df14_ft.iloc[12:24,3])
col_total2


#열의 형태로 들어가 있는 데이터 값을 행의 형태로 변경
for i in range(len(col_total)):
    if i%11 == 0:
        df14_ft.loc[i, f'{col_name[i]}'] = col_total[i]
    elif i%11 == 1:
        df14_ft.loc[i+11, f'{col_total2[i]}'] = col_total2[1+1] 
df14_ft

#최종 결과 확인 위해 테스트 엑셀파일 생성
df14_ft.T.to_csv("./df14_test.csv", encoding='euc-kr')
