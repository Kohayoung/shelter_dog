# %%
from selenium import webdriver

# %%
url = "http://www.hanatour.com/asp/booking/freestyle/freestyle-main.asp?hanacode=FIT_M_bi"

# %%
driver = webdriver.Chrome(executable_path="chromedriver.exe")

# %%
driver.get(url)

# %%
import requests

# %%
source=requests.get(url)
source
# Out:
# <Response [200]>

# %%
source.text
# Out:
# '<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd"><html>\r\n<head>\r\n<META http-equiv="Content-Type" content="text/html">\r\n<title> 하나투어 :: 1등 여행사 (주)하나투어 </title>\r\n<meta http-equiv="Content-Type" content="text/html; charset=euc-kr">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="keywords" content="해외여행, 해외자유여행, 자유여행, 에어텔, 해외항공권, 해외호텔, 해외현지투어, 해외입장권, 해외교통패스, 배낭여행, 렌터카, 일본료칸, 해외여행사, 해외여행땡처리, 땡처리특가, 여행사가격비교, 여행사, 해외여행추천">\r\n<meta name="description" content="하나투어 자유여행 브랜드, 하나Free! 항공+호텔+현지투어+패스/입장권 예약시 최대 30% 할인!">\r\n<meta name="title" content="">\r\n<meta property="og:image" content="">\r\n<link rel="stylesheet" type="text/css" href="http://image1.hanatour.com/2010/css/smoothness/jquery-ui-1.8.4.custom.css"><link rel="stylesheet" type="text/css" href="http://image1.hanatour.com/2010/css/jquery-ui.hanatour.css">\r\n<link rel="shortcut icon" href="http://image1.hanatour.com/2010/images/common/favicon.ico"
# ...

# %%
driver.find_element_by_css_selector('button.all_wholemenu').click()

# %%
list = driver.find_elements_by_css_selector('tbody tr ul.m_list li')

# %%
list_name = [a.text for a in list]
list_name[0]
# Out:
# '동남아/대만/서남아'

# %%
list[0].click()

# %%
list2 = driver.find_elements_by_css_selector('.nat_type_best_area .pd_list li')

# %%
list22 = [b.text for b in list2]
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-30-cc80d2b0048a> in <module>
# ----> 1 list22 = [b.text for b in list2]
#
# <ipython-input-30-cc80d2b0048a> in <listcomp>(.0)
# ----> 1 list22 = [b.text for b in list2]
#
# C:\ai\python\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# C:\ai\python\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ...

# %%
list2[0].click()
list2[0].find_element_by_class_name('btn_01').click()
