# %% [markdown]
# # 관악구 - 유기견의 수가 항상 높게 유지되는 이유 찾기

# %%
#%matplotlib inline
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

#파일 저장
import os
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgunsl.ttf').get_name()
mpl.rc('font', family=font_name)

df = pd.read_csv('merged_data/result_total.csv',  header=1, encoding='euc-kr' )
df
# Out:
#        년도   자치구      사람 수      남자수      여자수   유기견수    복귀  입양분양  폐사안락사  계류기증  \
# 0    2005    합계  10167344  5062492  5104852  14679   601   525   7736  5817
# 1    2005   종로구    169315    84981    84334    258    12     3     89   154
# 2    2005    중구    130027    64995    65032    264     0     9    102   153
# 3    2005   용산구    230260   113158   117102    383    12    12    170   189
# 4    2005   성동구    337744   169346   168398    431    19     7     96   309
# 5    2005   광진구    375613   187320   188293    788    47    16    290   435
# 6    2005  동대문구    381110   192317   188793    375     8    14    160   193
# 7    2005   중랑구    427373   213775   213598    658    27    17    591    23
# 8    2005   성북구    462879   230451   232428    564    19    10    148   387
# 9    2005   강북구    353260   175723   177537    576    22    11    521    22
# 10   2005   도봉구    381529   189766   191763    556    27    17    488    24
# 11   2005   노원구    622003   306356   315647    560    26    11    244   279
# 12   2005   은평구    470751   233418   237333    823    32    11    752    28
# 13   2005  서대문구    349163   171773   177390    596    24     7    146   419
# 14   2005   마포구    388164   190582   197582    557    17     5    529     6
# 15   2005   양천구    499755   250040   249715    843    28    12    767    36
# 16   2005   강서구    553660   274159   279501   1069    45     9    374   641
# 17   2005   구로구    416405   211109   205296    601    17     9    229   346
# 18   2005   금천구    256902   130883   126019    340     6     5    323     6
# 19   2005  영등포구    408386   206376   202010    588    16     8    268   296
# 20   2005   동작구    410481   203993   206488    679    26    11    616    26
# 21   2005   관악구    530020   270064   259956    717    25    16    240   436
# 22   2005   서초구    401736   196268   205468    359    19     7     77   256
# 23   2005   강남구    540909   262628   278281    581    48   277     89   167
# 24   2005   송파구    605840   299659   306181    791    38    16    195   542
# 25   2005   강동구    464059   233352   230707    722    41     5    232   444
# 26   2006    합계  10181166  5062107  5119059  11423   666   695   5310  4752
# 27   2006   종로구    166793    83634    83159    185    14     3     66   102
# 28   2006    중구    130649    65208    65441    148     7     3     29   109
# 29   2006   용산구    232035   114041   117994    296    13     6     96   181
# ..    ...   ...       ...      ...      ...    ...   ...   ...    ...   ...
# 334  2017   서초구    441102   211236   229866    130    49    26     55     1
# 335  2017   강남구    556164   266442   289722    146    52    40     54     -
# 336  2017   송파구    664496   323147   341349    227    71    55    101     -
# 337  2017   강동구    436223   216777   219446    255    84    59    111     1
# 338  2018    합계   9765623  4773899  4991724   5368  2017  1572   1703    76
# 339  2018   종로구    153065    74825    78240    122    50    23     49     -
# 340  2018    중구    125725    61947    63778     92    29    24     38     1
# 341  2018   용산구    228999   110640   118359    190    79    74     17    20
# 342  2018   성동구    308221   151359   156862    155    46    31     77     1
# 343  2018   광진구    355559   172794   182765    190    93    36     60     1
# 344  2018  동대문구    348052   173567   174485    237    91    57     86     3
# 345  2018   중랑구    403209   200419   202790    259    84    72    100     3
# 346  2018   성북구    435868   211904   223964    261    78    43    138     2
# 347  2018   강북구    319164   156071   163093    280    98    59    119     4
# 348  2018   도봉구    339413   166160   173253    204    76    45     82     1
# 349  2018   노원구    543752   263919   279833    222    63    49    109     1
# 350  2018   은평구    483197   233702   249495    285    95    52    133     5
# 351  2018  서대문구    310313   149569   160744    179    73    23     82     1
# 352  2018   마포구    375077   178240   196837    222   106    89     15    12
# 353  2018   양천구    464185   228634   235551    231   117   112      2     -
# 354  2018   강서구    596949   290079   306870    288    99    81    103     5
# 355  2018   구로구    404497   200417   204080    173    41    53     76     3
# 356  2018   금천구    233917   118915   115002    135    37    38     58     2
# 357  2018  영등포구    367778   183224   184554    139    50    44     43     2
# 358  2018   동작구    396203   192533   203670    227   118    67     42     -
# 359  2018   관악구    501957   252160   249797    493   207   275     11     -
# 360  2018   서초구    433951   207868   226083    124    42    15     64     3
# 361  2018   강남구    542364   259611   282753    158    58    41     57     2
# 362  2018   송파구    666635   323526   343109    211    57    62     90     2
# 363  2018   강동구    427573   211816   215757    291   130   107     52     2
#
#      ... 비거주용 건물내 주택_여 주택이외의 거처_남 주택이외의 거처_여    20세미만       20대       30대  \
# 0    ...           NaN        NaN        NaN      NaN       NaN       NaN
# 1    ...           NaN        NaN        NaN      NaN       NaN       NaN
# 2    ...           NaN        NaN        NaN      NaN       NaN       NaN
# 3    ...           NaN        NaN        NaN      NaN       NaN       NaN
# 4    ...           NaN        NaN        NaN      NaN       NaN       NaN
# 5    ...           NaN        NaN        NaN      NaN       NaN       NaN
# 6    ...           NaN        NaN        NaN      NaN       NaN       NaN
# 7    ...           NaN        NaN        NaN      NaN       NaN       NaN
# 8    ...           NaN        NaN        NaN      NaN       NaN       NaN
# 9    ...           NaN        NaN        NaN      NaN       NaN       NaN
# 10   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 11   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 12   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 13   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 14   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 15   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 16   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 17   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 18   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 19   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 20   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 21   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 22   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 23   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 24   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 25   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 26   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 27   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 28   ...           NaN        NaN        NaN      NaN       NaN       NaN
# 29   ...           NaN        NaN        NaN      NaN       NaN       NaN
# ..   ...           ...        ...        ...      ...       ...       ...
# 334  ...         716.0     2940.0     2519.0    537.0    8351.0   11380.0
# 335  ...        1116.0     4812.0     4498.0    539.0   12969.0   20358.0
# 336  ...         862.0     4806.0     4340.0    282.0   10387.0   16841.0
# 337  ...         553.0     2891.0     2242.0    162.0    5974.0    9058.0
# 338  ...       19913.0    96348.0    88026.0  14487.0  304497.0  273994.0
# 339  ...         457.0     2768.0     1925.0    798.0    7748.0    4467.0
# 340  ...         376.0     2412.0     1869.0    585.0    4946.0    4087.0
# 341  ...         305.0     2494.0     1890.0    307.0    7676.0    8577.0
# 342  ...         722.0     2571.0     2157.0    758.0   11285.0    8394.0
# 343  ...        1172.0     3029.0     3058.0    736.0   17721.0   13474.0
# 344  ...        1122.0     4251.0     3427.0   1844.0   18361.0    9233.0
# 345  ...         660.0     1878.0     1389.0    167.0    6537.0    9133.0
# 346  ...        1441.0     2347.0     2438.0   1616.0   18622.0    8540.0
# 347  ...         447.0     1650.0     1202.0    324.0    6451.0    6305.0
# 348  ...         258.0     1466.0      972.0    194.0    3461.0    4456.0
# 349  ...         342.0     1504.0      933.0    854.0   10053.0    6676.0
# 350  ...         500.0     3126.0     3392.0    235.0    7470.0    9976.0
# 351  ...         766.0     2076.0     2508.0    831.0   15995.0    7866.0
# 352  ...         867.0     4557.0     6163.0    782.0   17338.0   15487.0
# 353  ...         271.0     1546.0     1325.0    149.0    3941.0    6434.0
# 354  ...         392.0     9347.0    10789.0    270.0   15140.0   18490.0
# 355  ...         371.0     6224.0     5341.0    236.0    8320.0    9713.0
# 356  ...         345.0     4495.0     2818.0    104.0    6657.0    7206.0
# 357  ...         747.0     9312.0     7772.0    186.0   12973.0   14059.0
# 358  ...        1097.0     2457.0     1668.0   1108.0   19480.0   12873.0
# 359  ...        3988.0    10141.0     9072.0   1048.0   44034.0   29453.0
# 360  ...         703.0     3164.0     2883.0    504.0    8625.0   11800.0
# 361  ...        1165.0     4985.0     4935.0    421.0   13164.0   20173.0
# 362  ...         844.0     5549.0     5669.0    286.0   12058.0   18041.0
# 363  ...         555.0     2999.0     2431.0    144.0    6441.0    9081.0
#
#           40대       50대       60대     70대이상
# 0         NaN       NaN       NaN       NaN
# 1         NaN       NaN       NaN       NaN
# 2         NaN       NaN       NaN       NaN
# 3         NaN       NaN       NaN       NaN
# 4         NaN       NaN       NaN       NaN
# 5         NaN       NaN       NaN       NaN
# 6         NaN       NaN       NaN       NaN
# 7         NaN       NaN       NaN       NaN
# 8         NaN       NaN       NaN       NaN
# 9         NaN       NaN       NaN       NaN
# 10        NaN       NaN       NaN       NaN
# 11        NaN       NaN       NaN       NaN
# 12        NaN       NaN       NaN       NaN
# 13        NaN       NaN       NaN       NaN
# 14        NaN       NaN       NaN       NaN
# 15        NaN       NaN       NaN       NaN
# 16        NaN       NaN       NaN       NaN
# 17        NaN       NaN       NaN       NaN
# 18        NaN       NaN       NaN       NaN
# 19        NaN       NaN       NaN       NaN
# 20        NaN       NaN       NaN       NaN
# 21        NaN       NaN       NaN       NaN
# 22        NaN       NaN       NaN       NaN
# 23        NaN       NaN       NaN       NaN
# 24        NaN       NaN       NaN       NaN
# 25        NaN       NaN       NaN       NaN
# 26        NaN       NaN       NaN       NaN
# 27        NaN       NaN       NaN       NaN
# 28        NaN       NaN       NaN       NaN
# 29        NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...
# 334    7083.0    4610.0    3871.0    3870.0
# 335   10734.0    6579.0    5739.0    5856.0
# 336   10377.0    7868.0    6703.0    6390.0
# 337    6950.0    7168.0    6224.0    5514.0
# 338  173762.0  158875.0  146286.0  157520.0
# 339    3188.0    3261.0    2621.0    3243.0
# 340    2938.0    2869.0    2563.0    2815.0
# 341    5364.0    4249.0    3614.0    4453.0
# 342    5769.0    5400.0    4414.0    4686.0
# 343    7456.0    6710.0    5310.0    4930.0
# 344    6376.0    6494.0    6246.0    7039.0
# 345    7838.0    9788.0    8172.0    7572.0
# 346    6311.0    6252.0    6106.0    7689.0
# 347    5984.0    7069.0    7061.0    7678.0
# 348    4736.0    5685.0    5631.0    6685.0
# 349    6589.0    7428.0    8615.0   11065.0
# 350    7718.0    7471.0    7566.0    8452.0
# 351    5184.0    4529.0    4540.0    5850.0
# 352    8058.0    5231.0    4346.0    5595.0
# 353    5425.0    6028.0    6044.0    6283.0
# 354   10700.0    9412.0    9554.0    9445.0
# 355    6947.0    6568.0    6035.0    6332.0
# 356    5219.0    6184.0    4866.0    4328.0
# 357    7550.0    6802.0    5746.0    6161.0
# 358    6651.0    5422.0    5250.0    6088.0
# 359   12561.0    9599.0    7968.0    8070.0
# 360    7192.0    4776.0    4137.0    4103.0
# 361   10591.0    6413.0    5760.0    6205.0
# 362   10580.0    8130.0    7496.0    6860.0
# 363    6837.0    7105.0    6625.0    5893.0
#
# [364 rows x 77 columns]

# %%
from pyecharts import Bar3D
# Out:
# ERROR:lml.utils:failed to import pyecharts_snapshot
# Traceback (most recent call last):
#   File "D:\2019_multicampus\installed forder\2.1 anaconda\lib\site-packages\lml\utils.py", line 43, in do_import
#     plugin_module = __import__(plugin_module_name)
# ModuleNotFoundError: No module named 'pyecharts_snapshot'

# %%
# 2013년 이후 유기견 수가 400 마리를 유지하는 지역은 관악구뿐이다. 
#그 전년도인 용산구, 은평구, 양천구, 강동구도 400마리 이상 지역에 포함되었다.
#그럼 그 5개 지역의 데이터를 비교해보자.
#지역 관악구, 용산구, 은평구, 양천구, 강동구
#12년도에 비교할 수 있는 데이터는 인구수와 공원율 뿐이다.
#그럼 우선 구별, 년도별 인구수 비교해보자.

# %% [markdown]
# ## * 연도별/지역별/인구 수 3d 시각화

# %%
df_3d_person = df.iloc[:,[0,1,2]]

#예쁜 시각화를 위해 자치구가 '합계'인 ROW 삭제
df_3d_person = df_3d_person[df_3d_person['자치구'] != '합계']

#연도 컬럼을 인덱싱 -  자치구 값이 '합계'인 ROW 삭제 후 ROW INDEX도 삭제되어 리셋하기 위함 
df_3d_person= df_3d_person.set_index('년도')

#년도로 인덱싱된 데이터 프레임의 인덱스를 정수로 리셋
df_3d_person =df_3d_person.reset_index()
df_3d_person
# Out:
#        년도   자치구    사람 수
# 0    2005   종로구  169315
# 1    2005    중구  130027
# 2    2005   용산구  230260
# 3    2005   성동구  337744
# 4    2005   광진구  375613
# 5    2005  동대문구  381110
# 6    2005   중랑구  427373
# 7    2005   성북구  462879
# 8    2005   강북구  353260
# 9    2005   도봉구  381529
# 10   2005   노원구  622003
# 11   2005   은평구  470751
# 12   2005  서대문구  349163
# 13   2005   마포구  388164
# 14   2005   양천구  499755
# 15   2005   강서구  553660
# 16   2005   구로구  416405
# 17   2005   금천구  256902
# 18   2005  영등포구  408386
# 19   2005   동작구  410481
# 20   2005   관악구  530020
# 21   2005   서초구  401736
# 22   2005   강남구  540909
# 23   2005   송파구  605840
# 24   2005   강동구  464059
# 25   2006   종로구  166793
# 26   2006    중구  130649
# 27   2006   용산구  232035
# 28   2006   성동구  334437
# 29   2006   광진구  374442
# ..    ...   ...     ...
# 320  2017   관악구  503297
# 321  2017   서초구  441102
# 322  2017   강남구  556164
# 323  2017   송파구  664496
# 324  2017   강동구  436223
# 325  2018   종로구  153065
# 326  2018    중구  125725
# 327  2018   용산구  228999
# 328  2018   성동구  308221
# 329  2018   광진구  355559
# 330  2018  동대문구  348052
# 331  2018   중랑구  403209
# 332  2018   성북구  435868
# 333  2018   강북구  319164
# 334  2018   도봉구  339413
# 335  2018   노원구  543752
# 336  2018   은평구  483197
# 337  2018  서대문구  310313
# 338  2018   마포구  375077
# 339  2018   양천구  464185
# 340  2018   강서구  596949
# 341  2018   구로구  404497
# 342  2018   금천구  233917
# 343  2018  영등포구  367778
# 344  2018   동작구  396203
# 345  2018   관악구  501957
# 346  2018   서초구  433951
# 347  2018   강남구  542364
# 348  2018   송파구  666635
# 349  2018   강동구  427573
#
# [350 rows x 3 columns]

# %%
#축을 만들기 위해 연도, 자치구 리스트 뽑기
#연도, 지역 - 컬럼으로 추출
#X = df_year, Y = df_regiond, data = 인구 수
        
df_year = df_3d_person.drop_duplicates('년도', keep='first')['년도']
df_region = df_3d_person.drop_duplicates('자치구', keep='first')['자치구']
df_person_count = df_3d_person['사람 수']

print(df_year)
year_list = list(df_year)
region_list = list(df_region)
print(year_list)
print(region_list)
# Out:
# 0      2005
# 25     2006
# 50     2007
# 75     2008
# 100    2009
# 125    2010
# 150    2011
# 175    2012
# 200    2013
# 225    2014
# 250    2015
# 275    2016
# 300    2017
# 325    2018
# Name: 년도, dtype: int64
# [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
# ['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구']

# %%
#3d bar 그리기 위해 비수치 데이터 수치화(인덱스로 변경함)
df_3d_person['년도_num']=0
df_3d_person['자치구_num']=1
df_3d_person
# Out:
#        년도   자치구    사람 수  년도_num  자치구_num
# 0    2005   종로구  169315       0        1
# 1    2005    중구  130027       0        1
# 2    2005   용산구  230260       0        1
# 3    2005   성동구  337744       0        1
# 4    2005   광진구  375613       0        1
# 5    2005  동대문구  381110       0        1
# 6    2005   중랑구  427373       0        1
# 7    2005   성북구  462879       0        1
# 8    2005   강북구  353260       0        1
# 9    2005   도봉구  381529       0        1
# 10   2005   노원구  622003       0        1
# 11   2005   은평구  470751       0        1
# 12   2005  서대문구  349163       0        1
# 13   2005   마포구  388164       0        1
# 14   2005   양천구  499755       0        1
# 15   2005   강서구  553660       0        1
# 16   2005   구로구  416405       0        1
# 17   2005   금천구  256902       0        1
# 18   2005  영등포구  408386       0        1
# 19   2005   동작구  410481       0        1
# 20   2005   관악구  530020       0        1
# 21   2005   서초구  401736       0        1
# 22   2005   강남구  540909       0        1
# 23   2005   송파구  605840       0        1
# 24   2005   강동구  464059       0        1
# 25   2006   종로구  166793       0        1
# 26   2006    중구  130649       0        1
# 27   2006   용산구  232035       0        1
# 28   2006   성동구  334437       0        1
# 29   2006   광진구  374442       0        1
# ..    ...   ...     ...     ...      ...
# 320  2017   관악구  503297       0        1
# 321  2017   서초구  441102       0        1
# 322  2017   강남구  556164       0        1
# 323  2017   송파구  664496       0        1
# 324  2017   강동구  436223       0        1
# 325  2018   종로구  153065       0        1
# 326  2018    중구  125725       0        1
# 327  2018   용산구  228999       0        1
# 328  2018   성동구  308221       0        1
# 329  2018   광진구  355559       0        1
# 330  2018  동대문구  348052       0        1
# 331  2018   중랑구  403209       0        1
# 332  2018   성북구  435868       0        1
# 333  2018   강북구  319164       0        1
# 334  2018   도봉구  339413       0        1
# 335  2018   노원구  543752       0        1
# 336  2018   은평구  483197       0        1
# 337  2018  서대문구  310313       0        1
# 338  2018   마포구  375077       0        1
# 339  2018   양천구  464185       0        1
# 340  2018   강서구  596949       0        1
# 341  2018   구로구  404497       0        1
# 342  2018   금천구  233917       0        1
# 343  2018  영등포구  367778       0        1
# 344  2018   동작구  396203       0        1
# 345  2018   관악구  501957       0        1
# 346  2018   서초구  433951       0        1
# 347  2018   강남구  542364       0        1
# 348  2018   송파구  666635       0        1
# 349  2018   강동구  427573       0        1
#
# [350 rows x 5 columns]

# %%
#3d bar에 넣을 데이타 리스트 만들기
data_3d_person_list=[]
for i in range(len(df_3d_person)):
    data_row_list = list(df_3d_person.loc[i]) 
    #a = data_row_list[0]
    df_year_idx = list(df_year).index(data_row_list[0])
    df_region_idx = list(df_region).index(data_row_list[1])
    
    df_3d_person.loc[i,'년도_num'] = df_year_idx
    df_3d_person.loc[i,'자치구_num'] = df_region_idx
    
    data_3d_person_list.append([df_region_idx,df_year_idx,data_row_list[2]])
print(data_3d_person_list)
# Out:
# [[0, 0, 169315], [1, 0, 130027], [2, 0, 230260], [3, 0, 337744], [4, 0, 375613], [5, 0, 381110], [6, 0, 427373], [7, 0, 462879], [8, 0, 353260], [9, 0, 381529], [10, 0, 622003], [11, 0, 470751], [12, 0, 349163], [13, 0, 388164], [14, 0, 499755], [15, 0, 553660], [16, 0, 416405], [17, 0, 256902], [18, 0, 408386], [19, 0, 410481], [20, 0, 530020], [21, 0, 401736], [22, 0, 540909], [23, 0, 605840], [24, 0, 464059], [0, 1, 166793], [1, 1, 130649], [2, 1, 232035], [3, 1, 334437], [4, 1, 374442], [5, 1, 378860], [6, 1, 426078], [7, 1, 472843], [8, 1, 348990], [9, 1, 377534], [10, 1, 618093], [11, 1, 464580], [12, 1, 349020], [13, 1, 390583], [14, 1, 501717], [15, 1, 554945], [16, 1, 419832], [17, 1, 253243], [18, 1, 408698], [19, 1, 408582], [20, 1, 535217], [21, 1, 408266], [22, 1, 556964], [23, 1, 607005], [24, 1, 461760], [0, 2, 165846], [1, 2, 130044], [2, 2, 235832], [3, 2, 333535], [4, 2, 376572], [5, 2, 376421], [6, 2, 427071], [7, 2, 469973], [8, 2, 345478], [9, 2, 375975], [10, 2, 616753], [11, 2, 459196], [12, 2, 348575], [13, 2, 392650], [14, 2, 503650], [15, 2, 560424], [16, 2, 420542], [17, 2, 249108], [18, 2, 408178], [19, 2, 405967], [20, 2, 535571], [21, 2, 405969], [22, 2, 560958], [23, 2, 623876], [24, 2, 464546], [0, 3, 170705], [1, 3, 130362], [2, 3, 238224], [3, 3, 314212], [4, 3, 375482], [5, 3, 370250], [6, 3, 427871], [7, 3, 473357], [8, 3, 342274], [9, 3, 373936], [10, 3, 615981], [11, 3, 458401], [12, 3, 331688], [13, 3, 385119], [14, 3, 502343], [15, 3, 576848], [16, 3, 420795], [17, 3, 247320], [18, 3, 408099], [19, 3, 400866], [20, 3, 534556], [21, 3, 406320], [22, 3, 557832], [23, 3, 668962], [24, 3, 469024], [0, 4, 168603], [1, 4, 129465], [2, 4, 238708], [3, 4, 308058], [4, 4, 373998], [5, 4, 362146], [6, 4, 424761], [7, 4, 476028], [8, 4, 340367], [9, 4, 369733], [10, 4, 610616], [11, 4, 465895], [12, 4, 327451], [13, 4, 384013], [14, 4, 501395], [15, 4, 572836], [16, 4, 421967], [17, 4, 244835], [18, 4, 405798], [19, 4, 397920], [20, 4, 529869], [21, 4, 425481], [22, 4, 562138], [23, 4, 681476], [24, 4, 484745], [0, 5, 170578], [1, 5, 132822], [2, 5, 244853], [3, 5, 309093], [4, 5, 375463], [5, 5, 366786], [6, 5, 427455], [7, 5, 488932], [8, 5, 346520], [9, 5, 368298], [10, 5, 611230], [11, 5, 488109], [12, 5, 324541], [13, 5, 391865], [14, 5, 500001], [15, 5, 574127], [16, 5, 423736], [17, 5, 245195], [18, 5, 406833], [19, 5, 402709], [20, 5, 531434], [21, 5, 434720], [22, 5, 570095], [23, 5, 685279], [24, 5, 491871], [0, 6, 168382], [1, 6, 133193], [2, 6, 246501], [3, 6, 300711], [4, 6, 371936], [5, 6, 365486], [6, 6, 423706], [7, 6, 485171], [8, 6, 345054], [9, 6, 365573], [10, 6, 603930], [11, 6, 493634], [12, 6, 314852], [13, 6, 389493], [14, 6, 500210], [15, 6, 569072], [16, 6, 427468], [17, 6, 243438], [18, 6, 397443], [19, 6, 401408], [20, 6, 526397], [21, 6, 433564], [22, 6, 565710], [23, 6, 682209], [24, 6, 495138], [0, 7, 165207], [1, 7, 133360], [2, 7, 243232], [3, 7, 299604], [4, 7, 371313], [5, 7, 363258], [6, 7, 419295], [7, 7, 481857], [8, 7, 343157], [9, 7, 362270], [10, 7, 597189], [11, 7, 501480], [12, 7, 315113], [13, 7, 384644], [14, 7, 495911], [15, 7, 567431], [16, 7, 427520], [17, 7, 243288], [18, 7, 391408], [19, 7, 405491], [20, 7, 523029], [21, 7, 435044], [22, 7, 564197], [23, 7, 673115], [24, 7, 487905], [0, 8, 160070], [1, 8, 130465], [2, 8, 239740], [3, 8, 299337], [4, 8, 368927], [5, 8, 364273], [6, 8, 416798], [7, 8, 476589], [8, 8, 338707], [9, 8, 358582], [10, 8, 590479], [11, 8, 503660], [12, 8, 314110], [13, 8, 381856], [14, 8, 492528], [15, 8, 569070], [16, 8, 424964], [17, 8, 241020], [18, 8, 386471], [19, 8, 410815], [20, 8, 518028], [21, 8, 441763], [22, 8, 563599], [23, 8, 668415], [24, 8, 483379], [0, 9, 156993], [1, 9, 128065], [2, 9, 235951], [3, 9, 296086], [4, 9, 363354], [5, 9, 363687], [6, 9, 418836], [7, 9, 466706], [8, 9, 335025], [9, 9, 353709], [10, 9, 582552], [11, 9, 498644], [12, 9, 310376], [13, 9, 385439], [14, 9, 486221], [15, 9, 585160], [1 ...

# %%
# Tooltip callback 함수
# javascripthon을 사용하여 파이썬함수를 Javascript 함수로 변경한다.
#그래서 내부에 javascript 함수를 사용해도 괜찮다.
#콜백 함수이기 때문에 외부에서 데이터를 받아올 수 없다. 파라미터로 해결해야함. 그래서 index를 입력할 list는 직접 적어줌
def label_formatter(params):
    vals = params.value
    year_idx=vals[0]
    region_idx=vals[1]
    df_year_list = [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
    df_region_list =['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구']
    re_year = df_year_list[year_idx]
    re_region = df_region_list[region_idx]
    
    #result_str = '년도:'+str(re_year)+', 자치구:'+str(re_region)+', 유기견 수:'+vals[2]
    header_str = '''
                <div>
                  <span>구별 인구 수</span>
                  <br>
                '''
    result_str = header_str + params.marker + '<br>' + '- 년도 : '+re_year+'<br>'+'- 자치구 : '+re_region+' <br>'+'- 인구 수 : '+vals[2]+'명 <br></div>'
    return result_str

# %%
# 구별, 년도별 인구 수
bar3d_person = Bar3D("", width=1200, height=600)

x_axis = year_list #년도 2005-2018
y_axis = region_list #자치 구


data = data_3d_person_list
range_color = ['#313695', '#4575b4', '#74add1', '#abd9e9', '#e0f3f8', '#ffffbf',
               '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026']
bar3d_person.add(
    "구별, 년도별 인구 수",
    x_axis,
    y_axis,
    [[d[1], d[0], d[2]] for d in data],
    grid3d_width=100,
    grid3d_depth=250,
    
    datazoom_type='both',
    datazoom_orient='horizontal',
    
    #visualMap 설정
    is_visualmap=True,
    visual_range=[0, 600000],
    visual_range_color=range_color,
    visual_top='bottom',

    #x축 설정
    xaxis3d_name='년도',
    xaxis3d_interval=0,  #0으로 하면 모든 레이블 강제 표시 (axis3D 설정 봐야함)
    xaxis3d_margin=5,
    
    #y축 설정
    yaxis3d_name='자치구',
    yaxis3d_interval=0,
    
    #z축 설정
    zaxis3d_name='인구 수',
    
    #tooltip 설정
    tooltip_trigger='item',
    tooltip_formatter=label_formatter
)

#이건 전체 표출되는 화면 크기
bar3d_person.width=1000 #너비
bar3d_person.height=1000 #높이

bar3d_person
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'echartsgl': '/nbextensions/echarts/echarts-gl.min'
#         }
#     });
# </script>
#     <div id="dc8968b4c16049b898af354067f7bac1" style="width:1000px;height:1000px;"></div>
#
#
# <script>
#     require(['echarts', 'echartsgl'], function(echarts) {
#
# var myChart_dc8968b4c16049b898af354067f7bac1 = echarts.init(document.getElementById('dc8968b4c16049b898af354067f7bac1'), 'light', {renderer: 'canvas'});
# function label_formatter(params) {
#     var df_region_list, df_year_list, header_str, re_region, re_year, region_idx, result_str, vals, year_idx;
#     vals = params.value;
#     year_idx = vals[0];
#     region_idx = vals[1];
#     df_year_list = [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018];
#     df_region_list = ["\uc885\ub85c\uad6c", "\uc911\uad6c", "\uc6a9\uc0b0\uad6c", "\uc131\ub3d9\uad6c", "\uad11\uc9c4\uad6c", "\ub3d9\ub300\ubb38\uad6c", "\uc911\ub791\uad6c", "\uc131\ubd81\uad6c", "\uac15\ubd81\uad6c", "\ub3c4\ubd09\uad6c", "\ub178\uc6d0\uad6c", "\uc740\ud3c9\uad6c", "\uc11c\ub300\ubb38\uad6c", "\ub9c8\ud3ec\uad6c", "\uc591\ucc9c\uad6c", "\uac15\uc11c\uad6c", "\uad6c\ub85c\uad6c", "\uae08\ucc9c\uad6c", "\uc601\ub4f1\ud3ec\uad6c", "\ub3d9\uc791\uad6c", "\uad00\uc545\uad6c", "\uc11c\ucd08\uad6c", "\uac15\ub0a8\uad6c", "\uc1a1\ud30c\uad6c", "\uac15\ub3d9\uad6c"];
#     re_year = df_year_list[year_idx];
#     re_region = df_region_list[region_idx];
#     header_str = "\n                <div>\n                  <span>\uad6c\ubcc4 \uc778\uad6c \uc218</span>\n                  <br>\n                ";
#     result_str = (((((((((((header_str + params.marker) + "<br>") + "- \ub144\ub3c4 : ") + re_year) + "<br>") + "- \uc790\uce58\uad6c : ") + re_region) + " <br>") + "- \uc778\uad6c \uc218 : ") + vals[2]) + "\uba85 <br></div>");
#     return result_str;
# }
#
# var option_dc8968b4c16049b898af354067f7bac1 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3081058,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": label_formatter,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar3D",
#             "name": "\uad6c\ubcc4, \ub144\ub3c4\ubcc4 \uc778\uad6c \uc218",
#             "data": [
#                 [
#                     0,
#                     0,
#                     169315.0
#                 ],
#                 [
#                     0,
#                     1,
#                     130027.0
#                 ],
#                 [
#                     0,
#                     2,
#                     230260.0
#                 ],
#                 [
#                     0,
#                     3,
#                     337744.0
#                 ],
#                 [
#                     0,
#                     4,
#                     375613.0
#                 ],
#                 [
#                     0,
#                     5,
#                     381110.0
#                 ],
#                 [
#                     0,
#                     6,
#                     427373.0
#                 ],
#                 [
#                     0,
#                     7,
#                     462879.0
#                 ],
#                 [
#                     0,
#                     8,
#                     353260.0
#                 ],
#                 [
#                     0,
#                     9,
#                     381529.0
#                 ],
#                 [
#                     0,
#                     10,
#                     622003.0
#                 ],
#                 [
#                     0,
#                     11,
#                     470751.0
#                 ],
#                 [
#                     0,
#                     12,
#                     349163.0
#                 ],
#                 [
#                     0,
#                     13,
#                     388164.0
#                 ],
#                 [
#                     0,
#                     14,
#                     499755.0
#                 ],
#                 [
#                     0,
#                     15,
#                     553660.0
#                 ],
#                 [
#                     0,
#                     16,
#                     416405.0
#                 ],
#                 [
#                     0,
#                     17,
#                     256902.0
#                 ],
#                 [
#                     0,
#                     18,
#                     408386.0
#                 ],
#                 [
#                     0,
#                     19,
#                     410481.0
#                 ],
#                 [
#                     0,
#                     20,
#                     530020.0
#                 ],
#                 [
#                     0,
#                     21,
#                     401736.0
#                 ],
#                 [
#                     0,
#                     22,
#                     540909.0
#                 ],
#                 [
#                     0,
#                     23,
#                     605840.0
#                 ],
#                 [
#                     0,
#                     24,
#                     464059.0
#                 ],
#                 [
#                     1,
#                     0,
#                     166793.0
#                 ],
#                 [
#                     1,
#                     1,
#                     130649.0
#                 ],
#                 [
#                     1,
#                     2,
#                     232035.0
#                 ],
#                 [
#                     1,
#                     3,
#                     334437.0
#                 ],
#                 [
#                     1,
#                     4,
#                     374442.0
#                 ],
#                 [
#                     1,
#                     5,
#                     378860.0
#                 ],
#                 [
#                     1,
#                     6,
#                     426078.0
#                 ],
#                 [
#                     1,
#                     7,
#                     472843.0
#                 ],
#                 [
#                     1,
#                     8,
#                     348990.0
#                 ],
#                 [
#                     1,
#                     9,
#                     377534.0
#                 ],
#                 [
#                     1,
#                     10,
#                     618093.0
#                 ],
#                 [
#                     1,
#                     11,
#                     464580.0
#                 ],
#                 [
#                     1,
#                     12,
#                     349020.0
#                 ],
#                 [
#                     1,
#                     13,
#                     390583.0
#                 ],
#                 [
#                     1,
#                     14,
#                     501717.0
#                 ],
#                 [
#                     1,
#                     15,
#                     554945.0
#                 ],
#                 [
#                     1,
#                     16,
#                     419832.0
#                 ],
#                 [
#                     1,

# %% [markdown]
# #### 유기견 수가 2018년까지 많은 지역은 관악구이고,
# #### 2012년까지 유기견 400 마리 이상인 곳은 용산구, 은평구, 양천구, 강동구이다.
# #### 하지만, 인구가 가장 많은 곳은 송파구, 노원구와 강서구이고,
# #### 그 다음이 강남구, 관악구, 은평구, 강천구 등이다.
# #### 예상하기로 인구가 많으면 유기견의 수도 많을 거라 생각했지만 큰 상관 관계는 없다.

# %%
#구별, 년도 별 인구 대비 유기견 수  (유기견/인구수)
df_3d_ps_dog = df.iloc[:,[0,1,2,5]]

#예쁜 시각화를 위해 자치구가 '합계'인 ROW 삭제
#연도 컬럼을 인덱싱 -  자치구 값이 '합계'인 ROW 삭제 후 ROW INDEX도 삭제되어 리셋하기 위함 
#년도로 인덱싱된 데이터 프레임의 인덱스를 정수로 리셋
df_3d_ps_dog = df_3d_ps_dog[df_3d_ps_dog['자치구'] != '합계'].set_index('년도').reset_index()

#3d bar 그리기 위해 비수치 데이터 수치화(인덱스로 변경함)
df_3d_ps_dog['년도_num']=0
df_3d_ps_dog['자치구_num']=1
df_3d_ps_dog['dog_per_person']= df_3d_ps_dog['유기견수']/df_3d_ps_dog['사람 수']

df_3d_ps_dog
# Out:
#        년도   자치구    사람 수  유기견수  년도_num  자치구_num  dog_per_person
# 0    2005   종로구  169315   258       0        1        0.001524
# 1    2005    중구  130027   264       0        1        0.002030
# 2    2005   용산구  230260   383       0        1        0.001663
# 3    2005   성동구  337744   431       0        1        0.001276
# 4    2005   광진구  375613   788       0        1        0.002098
# 5    2005  동대문구  381110   375       0        1        0.000984
# 6    2005   중랑구  427373   658       0        1        0.001540
# 7    2005   성북구  462879   564       0        1        0.001218
# 8    2005   강북구  353260   576       0        1        0.001631
# 9    2005   도봉구  381529   556       0        1        0.001457
# 10   2005   노원구  622003   560       0        1        0.000900
# 11   2005   은평구  470751   823       0        1        0.001748
# 12   2005  서대문구  349163   596       0        1        0.001707
# 13   2005   마포구  388164   557       0        1        0.001435
# 14   2005   양천구  499755   843       0        1        0.001687
# 15   2005   강서구  553660  1069       0        1        0.001931
# 16   2005   구로구  416405   601       0        1        0.001443
# 17   2005   금천구  256902   340       0        1        0.001323
# 18   2005  영등포구  408386   588       0        1        0.001440
# 19   2005   동작구  410481   679       0        1        0.001654
# 20   2005   관악구  530020   717       0        1        0.001353
# 21   2005   서초구  401736   359       0        1        0.000894
# 22   2005   강남구  540909   581       0        1        0.001074
# 23   2005   송파구  605840   791       0        1        0.001306
# 24   2005   강동구  464059   722       0        1        0.001556
# 25   2006   종로구  166793   185       0        1        0.001109
# 26   2006    중구  130649   148       0        1        0.001133
# 27   2006   용산구  232035   296       0        1        0.001276
# 28   2006   성동구  334437   303       0        1        0.000906
# 29   2006   광진구  374442   637       0        1        0.001701
# ..    ...   ...     ...   ...     ...      ...             ...
# 320  2017   관악구  503297   450       0        1        0.000894
# 321  2017   서초구  441102   130       0        1        0.000295
# 322  2017   강남구  556164   146       0        1        0.000263
# 323  2017   송파구  664496   227       0        1        0.000342
# 324  2017   강동구  436223   255       0        1        0.000585
# 325  2018   종로구  153065   122       0        1        0.000797
# 326  2018    중구  125725    92       0        1        0.000732
# 327  2018   용산구  228999   190       0        1        0.000830
# 328  2018   성동구  308221   155       0        1        0.000503
# 329  2018   광진구  355559   190       0        1        0.000534
# 330  2018  동대문구  348052   237       0        1        0.000681
# 331  2018   중랑구  403209   259       0        1        0.000642
# 332  2018   성북구  435868   261       0        1        0.000599
# 333  2018   강북구  319164   280       0        1        0.000877
# 334  2018   도봉구  339413   204       0        1        0.000601
# 335  2018   노원구  543752   222       0        1        0.000408
# 336  2018   은평구  483197   285       0        1        0.000590
# 337  2018  서대문구  310313   179       0        1        0.000577
# 338  2018   마포구  375077   222       0        1        0.000592
# 339  2018   양천구  464185   231       0        1        0.000498
# 340  2018   강서구  596949   288       0        1        0.000482
# 341  2018   구로구  404497   173       0        1        0.000428
# 342  2018   금천구  233917   135       0        1        0.000577
# 343  2018  영등포구  367778   139       0        1        0.000378
# 344  2018   동작구  396203   227       0        1        0.000573
# 345  2018   관악구  501957   493       0        1        0.000982
# 346  2018   서초구  433951   124       0        1        0.000286
# 347  2018   강남구  542364   158       0        1        0.000291
# 348  2018   송파구  666635   211       0        1        0.000317
# 349  2018   강동구  427573   291       0        1        0.000681
#
# [350 rows x 7 columns]

# %%
#축을 만들기 위해 연도, 자치구 리스트 뽑기
#연도, 지역 - 컬럼으로 추출
#X = df_year, Y = df_regiond, data = 인구 수
        
df_year = df_3d_ps_dog.drop_duplicates('년도', keep='first')['년도']
df_region = df_3d_ps_dog.drop_duplicates('자치구', keep='first')['자치구']
df_person_count = df_3d_ps_dog['사람 수']

year_list = list(df_year)
region_list = list(df_region)
print(year_list)
print(region_list)
# Out:
# [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
# ['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구']

# %%
#3d bar에 넣을 데이타 리스트 만들기
df_3d_ps_dog_list=[]
for i in range(len(df_3d_ps_dog)):
    data_row_list = list(df_3d_ps_dog.loc[i]) 
    #print(data_row_list)
    #a = data_row_list[0]
    df_year_idx = list(df_year).index(data_row_list[0])
    df_region_idx = list(df_region).index(data_row_list[1])
    
    df_3d_ps_dog.loc[i,'년도_num'] = df_year_idx
    df_3d_ps_dog.loc[i,'자치구_num'] = df_region_idx
    
    df_3d_ps_dog_list.append([df_region_idx,df_year_idx,data_row_list[6]])
print(df_3d_ps_dog_list)
# Out:
# [[0, 0, 0.0015237870241856894], [1, 0, 0.0020303475432025654], [2, 0, 0.0016633370971944758], [3, 0, 0.0012761144535506181], [4, 0, 0.0020979039596606083], [5, 0, 0.0009839678832882894], [6, 0, 0.0015396386762851187], [7, 0, 0.001218460980083348], [8, 0, 0.0016305270905282228], [9, 0, 0.0014572942030618905], [10, 0, 0.0009003172010424388], [11, 0, 0.0017482703170041062], [12, 0, 0.001706939165948282], [13, 0, 0.001434960480621593], [14, 0, 0.0016868265450070534], [15, 0, 0.0019307878481378464], [16, 0, 0.00144330639641695], [17, 0, 0.0013234618648356182], [18, 0, 0.0014398142933401243], [19, 0, 0.0016541569524533414], [20, 0, 0.001352779140409796], [21, 0, 0.0008936216819005516], [22, 0, 0.001074117827582828], [23, 0, 0.0013056252475901228], [24, 0, 0.0015558366500811318], [0, 1, 0.0011091592572829794], [1, 1, 0.0011328062212493015], [2, 1, 0.0012756696188075075], [3, 1, 0.0009060002332277828], [4, 1, 0.0017011980493641206], [5, 1, 0.0011877738478593676], [6, 1, 0.0011969639361806993], [7, 1, 0.001070122641130354], [8, 1, 0.0014040516920255594], [9, 1, 0.0011654579455095434], [10, 1, 0.000679509394217375], [11, 1, 0.001470145077274097], [12, 1, 0.0013867400148988597], [13, 1, 0.0011649252527631772], [14, 1, 0.0011819412138715651], [15, 1, 0.0013352674589373723], [16, 1, 0.0011361687532155718], [17, 1, 0.00116488905912503], [18, 1, 0.0009102075371056379], [19, 1, 0.001150319886828103], [20, 1, 0.0010761989996580827], [21, 1, 0.0005609088192501947], [22, 1, 0.0009713374652580777], [23, 1, 0.0009621008064183986], [24, 1, 0.001165107415107415], [0, 2, 0.0009888691919009201], [1, 2, 0.0010996278182768908], [2, 2, 0.002289765595847892], [3, 2, 0.0008604794099569761], [4, 2, 0.001253412362044974], [5, 2, 0.0009776287720398172], [6, 2, 0.0009951506892296597], [7, 2, 0.0008149404327482643], [8, 2, 0.0012272850948540862], [9, 2, 0.0009096349491322562], [10, 2, 0.0006745001645715546], [11, 2, 0.0013588968545022169], [12, 2, 0.0011417915800043033], [13, 2, 0.0008888322933910608], [14, 2, 0.0009510572818425494], [15, 2, 0.0011259332219890653], [16, 2, 0.0009559092789780807], [17, 2, 0.0010758385920966007], [18, 2, 0.0008427695760183057], [19, 2, 0.001034566849029601], [20, 2, 0.000983996519602443], [21, 2, 0.0004951116957206092], [22, 2, 0.0007148485269841949], [23, 2, 0.0007229000634741519], [24, 2, 0.0009708403473498857], [0, 3, 0.0015465276353943938], [1, 3, 0.0012810481582056121], [2, 3, 0.0023297400765665928], [3, 3, 0.0007733632070067343], [4, 3, 0.0011105725440899964], [5, 3, 0.00100202565833896], [6, 3, 0.0009068153719228459], [7, 3, 0.0013900713415033474], [8, 3, 0.001560153561181977], [9, 3, 0.0009386633006717727], [10, 3, 0.000592550744259969], [11, 3, 0.0011540114441286123], [12, 3, 0.0015828127638021273], [13, 3, 0.001074992404944965], [14, 3, 0.0013616194512514359], [15, 3, 0.0009985299420297894], [16, 3, 0.001347449470644851], [17, 3, 0.000982532751091703], [18, 3, 0.0008576350346362034], [19, 3, 0.0013994701471314603], [20, 3, 0.0011729360441188575], [21, 3, 0.000691573144319748], [22, 3, 0.0009160464082376056], [23, 3, 0.0006323229122132498], [24, 3, 0.0014391587637306406], [0, 4, 0.0013463580126095028], [1, 4, 0.000888270961263662], [2, 4, 0.0022663672771754614], [3, 4, 0.0008602276194742549], [4, 4, 0.0009545505590938989], [5, 4, 0.000886382840070027], [6, 4, 0.0008852036792455051], [7, 4, 0.0008528910064113875], [8, 4, 0.0012633422159022468], [9, 4, 0.0007681218609104408], [10, 4, 0.0005928439477511235], [11, 4, 0.001983279494306657], [12, 4, 0.0014597603916311143], [13, 4, 0.0013358922744802911], [14, 4, 0.001152783733383859], [15, 4, 0.00100726909621602], [16, 4, 0.0012275841475755213], [17, 4, 0.00098842077317377], [18, 4, 0.0007097127142075614], [19, 4, 0.0014500402090872537], [20, 4, 0.0014814982571163815], [21, 4, 0.0004606551173847951], [22, 4, 0.0005585817005788615], [23, 4, 0.0007615822127264937], [24, 4, 0.0015554569928519118], [0, 5, 0.0016825147439880875], [1, 5, 0.0012046197166132116], [2, 5, 0.001882762310 ...

# %%
# Tooltip callback 함수
# javascripthon을 사용하여 파이썬함수를 Javascript 함수로 변경한다.
#그래서 내부에 javascript 함수를 사용해도 괜찮다.
#콜백 함수이기 때문에 외부에서 데이터를 받아올 수 없다. 파라미터로 해결해야함. 그래서 index를 입력할 list는 직접 적어줌
def label_formatter_ps_dog2(params):
    vals = params.value
    year_idx=vals[0]
    region_idx=vals[1]
    df_year_list = [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
    df_region_list =['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구']
    re_year = df_year_list[year_idx]
    re_region = df_region_list[region_idx]
    
    #result_str = '년도:'+str(re_year)+', 자치구:'+str(re_region)+', 유기견 수:'+vals[2]
    header_str = '''
                <div>
                  <span>인구대비 유기견 비율</span>
                  <br>
                '''
    result_str = header_str + params.marker + '<br>' + '- 년도 : '+re_year+'<br>'+'- 자치구 : '+re_region+' <br>'+'- 인구 대비 유기율 : '+(vals[2]*100)+'% <br></div>'
    return result_str

# %%
# 구별, 년도별 인구 수
bar3d_ps_dog = Bar3D("", width=1200, height=600)

x_axis = year_list #년도 2005-2018
y_axis = region_list #자치 구


data = df_3d_ps_dog_list
range_color = ['#313695', '#4575b4', '#74add1', '#abd9e9', '#e0f3f8', '#ffffbf',
               '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026']
bar3d_ps_dog.add(
    "구별, 년도별 인구 수",
    x_axis,
    y_axis,
    [[d[1], d[0], d[2]] for d in data],
    grid3d_width=100,
    grid3d_depth=250,
    
    datazoom_type='both',
    datazoom_orient='horizontal',
    
    #visualMap 설정
    is_visualmap=True,
    visual_range=[0, 0.003],
    visual_range_color=range_color,
    visual_top='bottom',

    #x축 설정
    xaxis3d_name='년도',
    xaxis3d_interval=0,  #0으로 하면 모든 레이블 강제 표시 (axis3D 설정 봐야함)
    xaxis3d_margin=5,
    
    #y축 설정
    yaxis3d_name='자치구',
    yaxis3d_interval=0,
    
    #z축 설정
    zaxis3d_name='인구 수',
    
    #tooltip 설정
    tooltip_trigger='item',
    tooltip_formatter=label_formatter_ps_dog2
)

#이건 전체 표출되는 화면 크기
bar3d_ps_dog.width=1000 #너비
bar3d_ps_dog.height=1000 #높이

bar3d_ps_dog
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'echartsgl': '/nbextensions/echarts/echarts-gl.min'
#         }
#     });
# </script>
#     <div id="b53cbfb37c694de18a7daa9aecf63da5" style="width:1000px;height:1000px;"></div>
#
#
# <script>
#     require(['echarts', 'echartsgl'], function(echarts) {
#
# var myChart_b53cbfb37c694de18a7daa9aecf63da5 = echarts.init(document.getElementById('b53cbfb37c694de18a7daa9aecf63da5'), 'light', {renderer: 'canvas'});
# function label_formatter_ps_dog2(params) {
#     var df_region_list, df_year_list, header_str, re_region, re_year, region_idx, result_str, vals, year_idx;
#     vals = params.value;
#     year_idx = vals[0];
#     region_idx = vals[1];
#     df_year_list = [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018];
#     df_region_list = ["\uc885\ub85c\uad6c", "\uc911\uad6c", "\uc6a9\uc0b0\uad6c", "\uc131\ub3d9\uad6c", "\uad11\uc9c4\uad6c", "\ub3d9\ub300\ubb38\uad6c", "\uc911\ub791\uad6c", "\uc131\ubd81\uad6c", "\uac15\ubd81\uad6c", "\ub3c4\ubd09\uad6c", "\ub178\uc6d0\uad6c", "\uc740\ud3c9\uad6c", "\uc11c\ub300\ubb38\uad6c", "\ub9c8\ud3ec\uad6c", "\uc591\ucc9c\uad6c", "\uac15\uc11c\uad6c", "\uad6c\ub85c\uad6c", "\uae08\ucc9c\uad6c", "\uc601\ub4f1\ud3ec\uad6c", "\ub3d9\uc791\uad6c", "\uad00\uc545\uad6c", "\uc11c\ucd08\uad6c", "\uac15\ub0a8\uad6c", "\uc1a1\ud30c\uad6c", "\uac15\ub3d9\uad6c"];
#     re_year = df_year_list[year_idx];
#     re_region = df_region_list[region_idx];
#     header_str = "\n                <div>\n                  <span>\uc778\uad6c\ub300\ube44 \uc720\uae30\uacac \ube44\uc728</span>\n                  <br>\n                ";
#     result_str = (((((((((((header_str + params.marker) + "<br>") + "- \ub144\ub3c4 : ") + re_year) + "<br>") + "- \uc790\uce58\uad6c : ") + re_region) + " <br>") + "- \uc778\uad6c \ub300\ube44 \uc720\uae30\uc728 : ") + (vals[2] * 100)) + "% <br></div>");
#     return result_str;
# }
#
# var option_b53cbfb37c694de18a7daa9aecf63da5 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6691230,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": label_formatter_ps_dog2,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar3D",
#             "name": "\uad6c\ubcc4, \ub144\ub3c4\ubcc4 \uc778\uad6c \uc218",
#             "data": [
#                 [
#                     0,
#                     0,
#                     0.0015237870241856894
#                 ],
#                 [
#                     0,
#                     1,
#                     0.0020303475432025654
#                 ],
#                 [
#                     0,
#                     2,
#                     0.0016633370971944758
#                 ],
#                 [
#                     0,
#                     3,
#                     0.0012761144535506181
#                 ],
#                 [
#                     0,
#                     4,
#                     0.0020979039596606083
#                 ],
#                 [
#                     0,
#                     5,
#                     0.0009839678832882894
#                 ],
#                 [
#                     0,
#                     6,
#                     0.0015396386762851187
#                 ],
#                 [
#                     0,
#                     7,
#                     0.001218460980083348
#                 ],
#                 [
#                     0,
#                     8,
#                     0.0016305270905282228
#                 ],
#                 [
#                     0,
#                     9,
#                     0.0014572942030618905
#                 ],
#                 [
#                     0,
#                     10,
#                     0.0009003172010424388
#                 ],
#                 [
#                     0,
#                     11,
#                     0.0017482703170041062
#                 ],
#                 [
#                     0,
#                     12,
#                     0.001706939165948282
#                 ],
#                 [
#                     0,
#                     13,
#                     0.001434960480621593
#                 ],
#                 [
#                     0,
#                     14,
#                     0.0016868265450070534
#                 ],
#                 [
#                     0,
#                     15,
#                     0.0019307878481378464
#                 ],
#                 [
#                     0,
#                     16,
#                     0.00144330639641695
#                 ],
#                 [
#                     0,
#                     17,
#                     0.0013234618648356182
#                 ],
#                 [
#                     0,
#                     18,
#                     0.0014398142933401243
#                 ],
#                 [
#                     0,
#                     19,
#                     0.0016541569524533414
#                 ],
#                 [
#                     0,
#                     20,
#                     0.001352779140409796
#                 ],
#                 [
#                     0,
#                     21,
#                     0.0008936216819005516
#                 ],
#                 [
#                     0,
#                     22,
#                     0.001074117827582828
#                 ],
#                 [
#                     0,
#                     23,
#                     0.0013056252475901228
#                 ],
#                 [
#                     0,
#                     24,
#                     0.0015558366500811318
#                 ],
#                 [
#                     1,
#                     0,
#                     0.0011091592572829794
#                 ],
#                 [
#                     1,
#                     1,
#                     0.0011328062212493015
#                 ],
#                 [
#                     1,
#                     2,
#                     0.0012756696188075075
#                 ],
#                 [
#                     1,
#                     3,
#                     0.0009060002332277828
#                 ],
#                 [
#                     1,
#                     4,
#                     0.0017011980493641206
#                 ],
#                 [
#                     1,
#                     5,
#                     0.0011877738478593676
#                 ],
#                 [
#                     1,
#                     6,
#                     0.0011969639361806993
#                 ],
#                 [
#                     1,
#                     7,
#                     0.001070122641130354
#                 ],
#                 [
#                     1,
#                     8,
#                     0.0014040516920255594
#                 ],
#                 [
#                     1,
#                     9,
#                     0.0011654579455095434
#                 ],
#                 [
#                     1,
#                     10,
#                     0.000679509394217375
#                 ],
#                 [
#                     1,
#                     11,
#                     0.001470145077274097
#                 ],
#                 [
#                     1,
#                     12,

# %% [markdown]
# #### 인구 대비 유기율 그래프를 보면 기존의 높았던 구들은 비슷하거나 더 낮은 그래프 유형을 나타내지만
# #### 인구가 낮았던 종로구나 중구에서 더 높은 수치가 나타남을 알 수 있다.
# #### 이 결과를 토대로 인구 수는 영향이 없다.
